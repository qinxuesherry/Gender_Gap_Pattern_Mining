# %%
import pandas as pd

# Load the CSV file to examine its structure
gap_list_df = pd.read_csv('../clean_data/gap_list.csv')
gap_list_df.head()
# Out:
#   Jurisdiction                                               Gaps
# 0      Alabama  [-8.0, -7.0, -6.0, -6.0, -9.0, -5.0, -8.0, -8....
# 1       Alaska  [-7.0, -13.0, -8.0, -9.0, -9.0, -8.0, -6.0, -6...
# 2      Arizona  [-11.0, -6.0, -8.0, -8.0, -6.0, -7.0, -6.0, -9...
# 3     Arkansas  [-6.0, -9.0, -8.0, -8.0, -11.0, -5.0, -8.0, -1...
# 4   California  [-4.0, -7.0, -7.0, -9.0, -6.0, -5.0, -6.0, -6....

# %%
# Correct the lambda function to handle float strings and convert them to integers
gap_list_df['Gaps'] = gap_list_df['Gaps'].apply(lambda x: [int(float(i)) for i in x.strip("[]").split(", ")])

# Define the years for which we want to expand the 'Gaps' list into separate columns
years = [2002, 2003, 2005, 2007, 2009, 2011, 2013, 2015, 2017, 2019, 2022]

# Expand the 'Gaps' list into separate columns for each year
for i, year in enumerate(years):
    gap_list_df[str(year)] = gap_list_df['Gaps'].apply(lambda x: x[i] if i < len(x) else None)

gap_list_df.drop(columns=['Gaps'], inplace=True)
# Display the head of the modified DataFrame to verify the changes
gap_list_df.head()
# Out:
#   Jurisdiction  2002  2003  2005  2007  2009  2011  2013  2015  2017  2019  \
# 0      Alabama    -8    -7    -6    -6    -9    -5    -8    -8    -7   -10
# 1       Alaska    -7   -13    -8    -9    -9    -8    -6    -6    -8    -7
# 2      Arizona   -11    -6    -8    -8    -6    -7    -6    -9    -5    -5
# 3     Arkansas    -6    -9    -8    -8   -11    -5    -8   -10    -9    -5
# 4   California    -4    -7    -7    -9    -6    -5    -6    -6    -9    -9
#
#    2022
# 0   -10
# 1   -13
# 2    -5
# 3    -9
# 4    -7

# %%
gap_list_df.to_csv('../clean_data/gap_list_year.csv')
