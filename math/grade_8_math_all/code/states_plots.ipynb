# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
data=pd.read_csv('../clean_data/after_clean.csv')
data.head()
# Out:
#    Year Jurisdiction  All students  Average scale score
# 0  2022     National  All students                274.0
# 1  2022      Alabama  All students                264.0
# 2  2022       Alaska  All students                270.0
# 3  2022      Arizona  All students                271.0
# 4  2022     Arkansas  All students                267.0

# %%
data['Year'] = data['Year'].astype(str)

# %%
# find out teh jurisdiction 
states=data['Jurisdiction'].unique()
print(len(states))
print(states)
# Out:
# 51
# ['National' 'Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho'
#  'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine'
#  'Maryland' 'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi'
#  'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey'
#  'New Mexico' 'New York' 'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma'
#  'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina' 'South Dakota'
#  'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia' 'Washington'
#  'West Virginia' 'Wisconsin' 'Wyoming']

# %%
# 5 states as a group for better plotting
states_1 = data['Jurisdiction'].unique()[:5]
states_2 = data['Jurisdiction'].unique()[5:10]
states_3 = data['Jurisdiction'].unique()[10:15]
states_4 = data['Jurisdiction'].unique()[15:20]
states_5 = data['Jurisdiction'].unique()[20:25]
states_6 = data['Jurisdiction'].unique()[25:30]
states_7 = data['Jurisdiction'].unique()[30:35]
states_8 = data['Jurisdiction'].unique()[35:40]
states_9 = data['Jurisdiction'].unique()[40:45]
states_10 = data['Jurisdiction'].unique()[45:]

# %%
# Pivot the data for plotting
pivot_data = data.pivot_table(index='Year', columns=['Jurisdiction'], values='Average scale score')

# %%
pivot_data.to_csv('../clean_data/pivot_data.csv')

# %%
pivot_data
# Out:
# Jurisdiction  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Year
# 2003            262.0   279.0    271.0     266.0       267.0     283.0
# 2005            262.0   279.0    274.0     272.0       269.0     281.0
# 2007            266.0   283.0    276.0     274.0       270.0     286.0
# 2009            269.0   283.0    277.0     276.0       270.0     287.0
# 2011            269.0   283.0    279.0     279.0       273.0     292.0
# 2013            269.0   282.0    280.0     278.0       276.0     290.0
# 2015            267.0   280.0    283.0     275.0       275.0     286.0
# 2017            268.0   277.0    282.0     274.0       277.0     286.0
# 2019            269.0   274.0    280.0     274.0       276.0     285.0
# 2022            264.0   270.0    271.0     267.0       270.0     275.0
#
# Jurisdiction  Connecticut  Delaware  Florida  Georgia  ...  South Dakota  \
# Year                                                   ...
# 2003                284.0     277.0    271.0    270.0  ...         285.0
# 2005                281.0     281.0    274.0    272.0  ...         287.0
# 2007                282.0     283.0    277.0    275.0  ...         288.0
# 2009                289.0     284.0    279.0    278.0  ...         291.0
# 2011                287.0     283.0    278.0    278.0  ...         291.0
# 2013                285.0     282.0    281.0    279.0  ...         287.0
# 2015                284.0     280.0    275.0    279.0  ...         285.0
# 2017                284.0     278.0    279.0    281.0  ...         286.0
# 2019                286.0     277.0    279.0    279.0  ...         287.0
# 2022                276.0     264.0    271.0    271.0  ...         281.0
#
# Jurisdiction  Tennessee  Texas   Utah  Vermont  Virginia  Washington  \
# Year
# 2003              268.0  277.0  281.0    286.0     282.0       281.0
# 2005              271.0  281.0  279.0    287.0     284.0       285.0
# 2007              274.0  286.0  281.0    291.0     288.0       285.0
# 2009              275.0  287.0  284.0    293.0     286.0       289.0
# 2011              274.0  290.0  283.0    294.0     289.0       288.0
# 2013              278.0  288.0  284.0    295.0     288.0       290.0
# 2015              278.0  284.0  286.0    290.0     288.0       287.0
# 2017              279.0  282.0  287.0    288.0     290.0       289.0
# 2019              280.0  280.0  285.0    287.0     287.0       286.0
# 2022              272.0  273.0  282.0    276.0     279.0       276.0
#
# Jurisdiction  West Virginia  Wisconsin  Wyoming
# Year
# 2003                  271.0      284.0    284.0
# 2005                  269.0      285.0    282.0
# 2007                  270.0      286.0    287.0
# 2009                  270.0      288.0    286.0
# 2011                  273.0      289.0    288.0
# 2013                  274.0      289.0    288.0
# 2015                  271.0      289.0    287.0
# 2017                  273.0      288.0    289.0
# 2019                  272.0      289.0    286.0
# 2022                  260.0      281.0    281.0
#
# [10 rows x 51 columns]

# %%
def plot(sample_states):
    fig, axes = plt.subplots(nrows=1, ncols=len(sample_states), figsize=(5 * len(sample_states), 10), sharey=True)
    fig.suptitle('Average Mathematics Score By Gender Over Time for Selected States', fontsize=16)
    colors=['#C497B2','#14517C']
    y_min,y_max=230,300
# Loop through the states to create horizontal subplots
    for ax, state in zip(axes, sample_states):
        pivot_data[state].plot(ax=ax, marker='o',color=colors)
        ax.set_title(state)
        ax.set_xlabel('Year')
        ax.set_ylabel('Average Scale Score')
        ax.set_ylim(y_min,y_max)
        ax.legend(title='Gender')

# Adjust the layout
    plt.style.use('my_style')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %%
plot(states_1)

# %%
plot(states_2)

# %%
plot(states_3)

# %%
plot(states_3)

# %%
plot(states_4)

# %%
plot(states_5)

# %%
plot(states_6)

# %%
plot(states_7)

# %%
plot(states_8)

# %%
plot(states_9)

# %%
plot(states_10)
