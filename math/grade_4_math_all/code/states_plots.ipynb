# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
data=pd.read_csv('../clean_data/after_clean.csv')
data.head()
# Out:
#    Year Jurisdiction  All students  Average scale score
# 0  2022     National  All students                236.0
# 1  2022      Alabama  All students                230.0
# 2  2022       Alaska  All students                226.0
# 3  2022      Arizona  All students                232.0
# 4  2022     Arkansas  All students                228.0

# %%
data['Year'] = data['Year'].astype(str)

# %%
# find out teh jurisdiction 
states=data['Jurisdiction'].unique()
print(len(states))
print(states)
# Out:
# 51
# ['National' 'Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California'
#  'Colorado' 'Connecticut' 'Delaware' 'Florida' 'Georgia' 'Hawaii' 'Idaho'
#  'Illinois' 'Indiana' 'Iowa' 'Kansas' 'Kentucky' 'Louisiana' 'Maine'
#  'Maryland' 'Massachusetts' 'Michigan' 'Minnesota' 'Mississippi'
#  'Missouri' 'Montana' 'Nebraska' 'Nevada' 'New Hampshire' 'New Jersey'
#  'New Mexico' 'New York' 'North Carolina' 'North Dakota' 'Ohio' 'Oklahoma'
#  'Oregon' 'Pennsylvania' 'Rhode Island' 'South Carolina' 'South Dakota'
#  'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia' 'Washington'
#  'West Virginia' 'Wisconsin' 'Wyoming']

# %%
# 5 states as a group for better plotting
states_1 = data['Jurisdiction'].unique()[:5]
states_2 = data['Jurisdiction'].unique()[5:10]
states_3 = data['Jurisdiction'].unique()[10:15]
states_4 = data['Jurisdiction'].unique()[15:20]
states_5 = data['Jurisdiction'].unique()[20:25]
states_6 = data['Jurisdiction'].unique()[25:30]
states_7 = data['Jurisdiction'].unique()[30:35]
states_8 = data['Jurisdiction'].unique()[35:40]
states_9 = data['Jurisdiction'].unique()[40:45]
states_10 = data['Jurisdiction'].unique()[45:]

# %%
# Pivot the data for plotting
pivot_data = data.pivot_table(index='Year', columns=['Jurisdiction'], values='Average scale score')

# %%
pivot_data.to_csv('../clean_data/pivot_data.csv')

# %%
pivot_data
# Out:
# Jurisdiction  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# Year
# 2003            223.0   233.0    229.0     229.0       227.0     235.0
# 2005            225.0   236.0    230.0     236.0       230.0     239.0
# 2007            229.0   237.0    232.0     238.0       230.0     240.0
# 2009            228.0   237.0    230.0     238.0       232.0     243.0
# 2011            231.0   236.0    235.0     238.0       234.0     244.0
# 2013            233.0   236.0    240.0     240.0       234.0     247.0
# 2015            231.0   236.0    238.0     235.0       232.0     242.0
# 2017            232.0   230.0    234.0     234.0       232.0     241.0
# 2019            230.0   232.0    238.0     233.0       235.0     242.0
# 2022            230.0   226.0    232.0     228.0       230.0     236.0
#
# Jurisdiction  Connecticut  Delaware  Florida  Georgia  ...  South Dakota  \
# Year                                                   ...
# 2003                241.0     236.0    234.0    230.0  ...         237.0
# 2005                242.0     240.0    239.0    234.0  ...         242.0
# 2007                243.0     242.0    242.0    235.0  ...         241.0
# 2009                245.0     239.0    242.0    236.0  ...         242.0
# 2011                242.0     240.0    240.0    238.0  ...         241.0
# 2013                243.0     243.0    242.0    240.0  ...         241.0
# 2015                240.0     239.0    243.0    236.0  ...         240.0
# 2017                239.0     236.0    246.0    236.0  ...         242.0
# 2019                243.0     239.0    246.0    238.0  ...         241.0
# 2022                236.0     226.0    241.0    235.0  ...         239.0
#
# Jurisdiction  Tennessee  Texas   Utah  Vermont  Virginia  Washington  \
# Year
# 2003              228.0  237.0  235.0    242.0     239.0       238.0
# 2005              232.0  242.0  239.0    244.0     240.0       242.0
# 2007              233.0  242.0  239.0    246.0     244.0       243.0
# 2009              232.0  240.0  240.0    248.0     243.0       242.0
# 2011              233.0  241.0  243.0    247.0     245.0       243.0
# 2013              240.0  242.0  243.0    248.0     246.0       246.0
# 2015              241.0  244.0  243.0    243.0     247.0       245.0
# 2017              237.0  241.0  242.0    241.0     248.0       242.0
# 2019              240.0  244.0  244.0    239.0     247.0       240.0
# 2022              236.0  239.0  240.0    234.0     236.0       235.0
#
# Jurisdiction  West Virginia  Wisconsin  Wyoming
# Year
# 2003                  231.0      237.0    241.0
# 2005                  231.0      241.0    243.0
# 2007                  236.0      244.0    244.0
# 2009                  233.0      244.0    242.0
# 2011                  235.0      245.0    244.0
# 2013                  237.0      245.0    247.0
# 2015                  235.0      243.0    247.0
# 2017                  236.0      240.0    248.0
# 2019                  231.0      242.0    246.0
# 2022                  226.0      240.0    243.0
#
# [10 rows x 51 columns]

# %%
def plot(sample_states):
    fig, axes = plt.subplots(nrows=1, ncols=len(sample_states), figsize=(5 * len(sample_states), 10), sharey=True)
    fig.suptitle('Average Mathematics Score By Gender Over Time for Selected States', fontsize=16)
    colors=['#C497B2','#14517C']
    y_min,y_max=200,250
# Loop through the states to create horizontal subplots
    for ax, state in zip(axes, sample_states):
        pivot_data[state].plot(ax=ax, marker='o',color=colors)
        ax.set_title(state)
        ax.set_xlabel('Year')
        ax.set_ylabel('Average Scale Score')
        ax.set_ylim(y_min,y_max)
        ax.legend(title='Gender')

# Adjust the layout
    plt.style.use('my_style')
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %%
plot(states_1)

# %%
plot(states_2)

# %%
plot(states_3)

# %%
plot(states_3)

# %%
plot(states_4)

# %%
plot(states_5)

# %%
plot(states_6)

# %%
plot(states_7)

# %%
plot(states_8)

# %%
plot(states_9)

# %%
plot(states_10)
